# %%
import nltk
# nltk.download('popular')

import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
data = open('artikel.txt', 'r')
artikel = data.read()
print(artikel)
# Out:
# Teknologi memanglah terus menjadi tumbuh dengan pesat Bermacam fitur serta kecanggihan baru ditawarkan bermacam web ataupun aplikasiKecanggihan yang ditawarkan tersebut pasti berasal dari bahasa pemrograman yang diaplikasikan Ada banyak bahasa pemrograman yang dapat digunakan tetapi Python jadi salah satu yang lumayan terkenalSaat sebelum mangulas lebih jauh sesungguhnya apa itu Python serta seberapa berartinya bahasa ini buat dipelajari?Pada postingan ini Glints telah bagikan penjelasannya untukmu!Sesungguhnya Python tidaklah bahasa pemrograman baru Bagi Geeksforgeeks Python sendiri telah terdapat lumayan lama sejak tahun 1991Bahasa pemrograman yang dibesarkan oleh Guido van Rossum ini terus hadapi pembaruan sampai dikala ini Nama Python sendiri diambil dari prorgam tv favoritnya yang bernama Monty Python Flying CircusPython merupakan bahasa pemrograman yang terkenal digunakan di segala dunia buat meningkatkan web website algoritma serta menyederhanakan proses otomatisasiLewat bahasa pemrograman Python tiap program hendak jadi lebih ringkas bila dibanding bahasa pemrograman lainTidak hanyaitu Python bertujuan buat menciptakan kode yang lebih jelas serta lebih logis buat bermacam keperluanProses pengkodean Python sangat simpel sehingga membagikan keleluasaan untuk pengembang buat meningkatkan fitur baru dari sesuatu web ataupun aplikasiPython banyak diaplikasikan pada bermacam sistem pembedahan semacam Linux Microsoft Windows Mac OS Android Symbian OS Amiga Palm serta lain- lainDengan kemudahan yang diberikan tidak heran Python lebih gampang dipelajari oleh pendatang baruDalam perkembangannya Python tidak cuma digunakan dalam dunia teknologi tetapi pula dalam perihal lain spesialnya analisisSaking gampang serta uniknya Python tidak heran bila banyak raksasa teknologi pula memakainyaSemacam dipaparkan tadinya berartinya Python tidak cuma terbatas buat urusan teknologi sajaAda banyak perihal yang bisa dipermudah dengan mempraktikkan bahasa pemrograman tersebut di dalamnyaBerikut merupakan sebagian khasiat Python sehingga berarti buat dipelajari 1 Pengembangan websiteDalam membangun bisnis terdapatnya web pasti jadi faktor berarti di dalamnya Tidak hanya selaku pemberi data kepada calon konsumen web pula menampilkan kredibilitas industriTidak tidak sering bermacam web buat bisnis juga diberikan bermacam berbagai fitur supaya wisatawan bisa lebih menguasai bisnis yang dijalankanBuat meningkatkan sesuatu web supaya lebih intuitif serta menarik memakai Python hendak memudahkan prosesnya2 Pengembangan IoTPerihal lain yang membuktikan berartinya Python merupakan pengembangan internet of things IoTInternet of things merupakan suatu sistem di mana bermacam barang ataupun perlengkapan bisa berbicara satu sama lain dengan piranti internetBuat meningkatkan perihal tersebut Python digunakan sebab bermacam kemudahan serta fleksibilitasnya3 Penambangan dataPerihal lain yang tercantum dalam khasiat Python merupakan pengaturan serta pembersihan informasiPython dikira selaku salah satu bahasa pemrograman terbaik buat mengerjakannya Tidak hanya itu pendidikan mesin dengan Python menyederhanakan analisis informasi dengan memakai algoritma4 Pengembangan machine learningMasih berkaitan dengan penambangan informasi dalam melaksanakan machine learning hendak diperlukan bermacam- macam informasi buat diinputBermacam- macam informasi yang masuk setelah itu diolah buat jadi sesuatu aksi yang dicoba oleh mesin tersebutDalam prosesnya buat memudahkan proses ini bahasa pemrograman Python- lah yang digunakan5 Pengembangan gameNyatanya Python pula bermanfaat buat meningkatkan permainan yang kalian mainkan Dalam Python ada program yang bernama GUIAntarmuka pengguna grafis graphical user interface/ GUI membolehkan orang buat berhubungan dengan pc memakai elemen visual semacam ikon ataupun foto alih- alih perintah berbasis bacaanInilah yang membuat permainan yang kalian mainkan jadi lebih atraktif serta menantang6 Python buat fintechBerartinya Python tergambar p ...

# %%
word_tokens = word_tokenize(artikel)
print(word_tokens)
# Out:
# ['Teknologi', 'memanglah', 'terus', 'menjadi', 'tumbuh', 'dengan', 'pesat', 'Bermacam', 'fitur', 'serta', 'kecanggihan', 'baru', 'ditawarkan', 'bermacam', 'web', 'ataupun', 'aplikasiKecanggihan', 'yang', 'ditawarkan', 'tersebut', 'pasti', 'berasal', 'dari', 'bahasa', 'pemrograman', 'yang', 'diaplikasikan', 'Ada', 'banyak', 'bahasa', 'pemrograman', 'yang', 'dapat', 'digunakan', 'tetapi', 'Python', 'jadi', 'salah', 'satu', 'yang', 'lumayan', 'terkenalSaat', 'sebelum', 'mangulas', 'lebih', 'jauh', 'sesungguhnya', 'apa', 'itu', 'Python', 'serta', 'seberapa', 'berartinya', 'bahasa', 'ini', 'buat', 'dipelajari', '?', 'Pada', 'postingan', 'ini', 'Glints', 'telah', 'bagikan', 'penjelasannya', 'untukmu', '!', 'Sesungguhnya', 'Python', 'tidaklah', 'bahasa', 'pemrograman', 'baru', 'Bagi', 'Geeksforgeeks', 'Python', 'sendiri', 'telah', 'terdapat', 'lumayan', 'lama', 'sejak', 'tahun', '1991Bahasa', 'pemrograman', 'yang', 'dibesarkan', 'oleh', 'Guido', 'van', 'Rossum', 'ini', 'terus', 'hadapi', 'pembaruan', 'sampai', 'dikala', 'ini', 'Nama', 'Python', 'sendiri', 'diambil', 'dari', 'prorgam', 'tv', 'favoritnya', 'yang', 'bernama', 'Monty', 'Python', 'Flying', 'CircusPython', 'merupakan', 'bahasa', 'pemrograman', 'yang', 'terkenal', 'digunakan', 'di', 'segala', 'dunia', 'buat', 'meningkatkan', 'web', 'website', 'algoritma', 'serta', 'menyederhanakan', 'proses', 'otomatisasiLewat', 'bahasa', 'pemrograman', 'Python', 'tiap', 'program', 'hendak', 'jadi', 'lebih', 'ringkas', 'bila', 'dibanding', 'bahasa', 'pemrograman', 'lainTidak', 'hanyaitu', 'Python', 'bertujuan', 'buat', 'menciptakan', 'kode', 'yang', 'lebih', 'jelas', 'serta', 'lebih', 'logis', 'buat', 'bermacam', 'keperluanProses', 'pengkodean', 'Python', 'sangat', 'simpel', 'sehingga', 'membagikan', 'keleluasaan', 'untuk', 'pengembang', 'buat', 'meningkatkan', 'fitur', 'baru', 'dari', 'sesuatu', 'web', 'ataupun', 'aplikasiPython', 'banyak', 'diaplikasikan', 'pada', 'bermacam', 'sistem', 'pembedahan', 'semacam', 'Linux', 'Microsoft', 'Windows', 'Mac', 'OS', 'Android', 'Symbian', 'OS', 'Amiga', 'Palm', 'serta', 'lain-', 'lainDengan', 'kemudahan', 'yang', 'diberikan', 'tidak', 'heran', 'Python', 'lebih', 'gampang', 'dipelajari', 'oleh', 'pendatang', 'baruDalam', 'perkembangannya', 'Python', 'tidak', 'cuma', 'digunakan', 'dalam', 'dunia', 'teknologi', 'tetapi', 'pula', 'dalam', 'perihal', 'lain', 'spesialnya', 'analisisSaking', 'gampang', 'serta', 'uniknya', 'Python', 'tidak', 'heran', 'bila', 'banyak', 'raksasa', 'teknologi', 'pula', 'memakainyaSemacam', 'dipaparkan', 'tadinya', 'berartinya', 'Python', 'tidak', 'cuma', 'terbatas', 'buat', 'urusan', 'teknologi', 'sajaAda', 'banyak', 'perihal', 'yang', 'bisa', 'dipermudah', 'dengan', 'mempraktikkan', 'bahasa', 'pemrograman', 'tersebut', 'di', 'dalamnyaBerikut', 'merupakan', 'sebagian', 'khasiat', 'Python', 'sehingga', 'berarti', 'buat', 'dipelajari', '1', 'Pengembangan', 'websiteDalam', 'membangun', 'bisnis', 'terdapatnya', 'web', 'pasti', 'jadi', 'faktor', 'berarti', 'di', 'dalamnya', 'Tidak', 'hanya', 'selaku', 'pemberi', 'data', 'kepada', 'calon', 'konsumen', 'web', 'pula', 'menampilkan', 'kredibilitas', 'industriTidak', 'tidak', 'sering', 'bermacam', 'web', 'buat', 'bisnis', 'juga', 'diberikan', 'bermacam', 'berbagai', 'fitur', 'supaya', 'wisatawan', 'bisa', 'lebih', 'menguasai', 'bisnis', 'yang', 'dijalankanBuat', 'meningkatkan', 'sesuatu', 'web', 'supaya', 'lebih', 'intuitif', 'serta', 'menarik', 'memakai', 'Python', 'hendak', 'memudahkan', 'prosesnya2', 'Pengembangan', 'IoTPerihal', 'lain', 'yang', 'membuktikan', 'berartinya', 'Python', 'merupakan', 'pengembangan', 'internet', 'of', 'things', 'IoTInternet', 'of', 'things', 'merupakan', 'suatu', 'sistem', 'di', 'mana', 'bermacam', 'barang', 'ataupun', 'perlengkapan', 'bisa', 'berbicara', 'satu', 'sama', 'lain', 'dengan', 'piranti', 'internetBuat', 'meningkatkan', 'perihal', 'tersebut', 'Python', 'digunakan', 'sebab', 'bermacam', 'kemudahan', 'serta', 'fleksibilitasnya3', 'Penambangan', 'd ...

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['Teknologi', 'memanglah', 'tumbuh', 'pesat', 'Bermacam', 'fitur', 'kecanggihan', 'ditawarkan', 'web', 'aplikasiKecanggihan', 'ditawarkan', 'berasal', 'bahasa', 'pemrograman', 'diaplikasikan', 'Ada', 'bahasa', 'pemrograman', 'Python', 'salah', 'lumayan', 'terkenalSaat', 'mangulas', 'sesungguhnya', 'Python', 'berartinya', 'bahasa', 'dipelajari', '?', 'Pada', 'postingan', 'Glints', 'bagikan', 'penjelasannya', 'untukmu', '!', 'Sesungguhnya', 'Python', 'bahasa', 'pemrograman', 'Bagi', 'Geeksforgeeks', 'Python', 'lumayan', '1991Bahasa', 'pemrograman', 'dibesarkan', 'Guido', 'van', 'Rossum', 'hadapi', 'pembaruan', 'dikala', 'Nama', 'Python', 'diambil', 'prorgam', 'tv', 'favoritnya', 'bernama', 'Monty', 'Python', 'Flying', 'CircusPython', 'bahasa', 'pemrograman', 'terkenal', 'dunia', 'meningkatkan', 'web', 'website', 'algoritma', 'menyederhanakan', 'proses', 'otomatisasiLewat', 'bahasa', 'pemrograman', 'Python', 'program', 'ringkas', 'dibanding', 'bahasa', 'pemrograman', 'lainTidak', 'hanyaitu', 'Python', 'bertujuan', 'menciptakan', 'kode', 'logis', 'keperluanProses', 'pengkodean', 'Python', 'simpel', 'membagikan', 'keleluasaan', 'pengembang', 'meningkatkan', 'fitur', 'web', 'aplikasiPython', 'diaplikasikan', 'sistem', 'pembedahan', 'Linux', 'Microsoft', 'Windows', 'Mac', 'OS', 'Android', 'Symbian', 'OS', 'Amiga', 'Palm', 'lain-', 'lainDengan', 'kemudahan', 'heran', 'Python', 'gampang', 'dipelajari', 'pendatang', 'baruDalam', 'perkembangannya', 'Python', 'dunia', 'teknologi', 'perihal', 'spesialnya', 'analisisSaking', 'gampang', 'uniknya', 'Python', 'heran', 'raksasa', 'teknologi', 'memakainyaSemacam', 'dipaparkan', 'berartinya', 'Python', 'terbatas', 'urusan', 'teknologi', 'sajaAda', 'perihal', 'dipermudah', 'mempraktikkan', 'bahasa', 'pemrograman', 'dalamnyaBerikut', 'khasiat', 'Python', 'dipelajari', '1', 'Pengembangan', 'websiteDalam', 'membangun', 'bisnis', 'terdapatnya', 'web', 'faktor', 'dalamnya', 'Tidak', 'pemberi', 'data', 'calon', 'konsumen', 'web', 'menampilkan', 'kredibilitas', 'industriTidak', 'web', 'bisnis', 'fitur', 'wisatawan', 'menguasai', 'bisnis', 'dijalankanBuat', 'meningkatkan', 'web', 'intuitif', 'menarik', 'memakai', 'Python', 'memudahkan', 'prosesnya2', 'Pengembangan', 'IoTPerihal', 'membuktikan', 'berartinya', 'Python', 'pengembangan', 'internet', 'of', 'things', 'IoTInternet', 'of', 'things', 'sistem', 'barang', 'perlengkapan', 'berbicara', 'piranti', 'internetBuat', 'meningkatkan', 'perihal', 'Python', 'kemudahan', 'fleksibilitasnya3', 'Penambangan', 'dataPerihal', 'tercantum', 'khasiat', 'Python', 'pengaturan', 'pembersihan', 'informasiPython', 'salah', 'bahasa', 'pemrograman', 'terbaik', 'mengerjakannya', 'Tidak', 'pendidikan', 'mesin', 'Python', 'menyederhanakan', 'analisis', 'informasi', 'memakai', 'algoritma4', 'Pengembangan', 'machine', 'learningMasih', 'berkaitan', 'penambangan', 'informasi', 'melaksanakan', 'machine', 'learning', 'bermacam-', 'informasi', 'diinputBermacam-', 'informasi', 'masuk', 'diolah', 'aksi', 'dicoba', 'mesin', 'tersebutDalam', 'prosesnya', 'memudahkan', 'proses', 'bahasa', 'pemrograman', 'Python-', 'digunakan5', 'Pengembangan', 'gameNyatanya', 'Python', 'bermanfaat', 'meningkatkan', 'permainan', 'mainkan', 'Dalam', 'Python', 'program', 'bernama', 'GUIAntarmuka', 'pengguna', 'grafis', 'graphical', 'user', 'interface/', 'GUI', 'membolehkan', 'orang', 'berhubungan', 'pc', 'memakai', 'elemen', 'visual', 'ikon', 'foto', 'alih-', 'alih', 'perintah', 'berbasis', 'bacaanInilah', 'permainan', 'mainkan', 'atraktif', 'menantang6', 'Python', 'fintechBerartinya', 'Python', 'tergambar', 'pengembangan', 'fintech', 'Dengan', 'memakai', 'Python', 'aplikasi', 'fitur', 'fintech', 'nyamanTidak', 'fintech', 'membutuhkan', 'pengoperasian', 'kilat', 'Python-', 'bersamaan', 'kemampuannya', 'menunjang', 'perihal', 'ituBaca', 'Pula', ':', 'Mengawali', 'Karier', 'Front', 'End', 'DeveloperKeunggulan', 'KekuranganKeunggulan', 'PythonMenyadur', 'Pyhton', 'org', 'Python', 'bahasa', 'pemrograman', 'gampang ...

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)

print(freq_kata_1.most_common(20))
print(freq_kata_2.most_common(20))
# Out:
# [('yang', 27), ('Python', 26), ('buat', 18), ('serta', 14), ('bahasa', 12), ('pemrograman', 11), ('dengan', 10), ('lebih', 9), ('bermacam', 8), ('web', 7), ('jadi', 6), ('ini', 6), ('di', 6), ('dari', 5), ('banyak', 5), ('digunakan', 5), ('itu', 5), ('merupakan', 5), ('meningkatkan', 5), ('tidak', 5)]
# [('Python', 26), ('bahasa', 12), ('pemrograman', 11), ('web', 7), ('meningkatkan', 5), ('gampang', 5), ('fitur', 4), ('dipelajari', 4), ('perihal', 4), ('Pengembangan', 4), ('memakai', 4), ('informasi', 4), ('lumayan', 3), ('berartinya', 3), ('teknologi', 3), ('bisnis', 3), ('pengembangan', 3), ('fintech', 3), ('ditawarkan', 2), ('diaplikasikan', 2)]

# %%
freq_kata_1.plot(20)
freq_kata_2.plot(20)

plt.show()
